# %%
using PyPlot
# Out:
# INFO: Loading help data...

# %%
sixtyV = readdlm("60V.dat")
sixtymA=readdlm("60mA.dat")
fiftymA=readdlm("50mA.dat")
fourtymA=readdlm("40mA.dat");

# %%
V1=zeros(63)
I1=zeros(63)
for i in 1:63
    V1[i]=sixtyV[i,1]
    I1[i]=sixtyV[i,2]
end 
plot(V1,I1,"b.--")
#semilogy(V1,I1,"r.--")
grid("on")
title(L"67 \ mA ",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11983c4d0>)

# %%
V2=zeros(63)
I2=zeros(63)
for i in 1:63
    V2[i]=sixtyV[i,1]
    I2[i]=sixtyV[i,3]
end 
plot(V2,I2,"b.--")
title(L"69.1 \ mA \ (1ra \ corrida)",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
grid("on")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1195ed9d0>)

# %%
V3=zeros(63)
I3=zeros(63)
for i in 1:63
    V3[i]=sixtyV[i,1]
    I3[i]=sixtyV[i,4]
end 
plot(V3,I3,"b.--")
title(L"69.1 \ mA \ (2ra \ corrida)",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1198c2a90>)

# %%
plot(V1,I1,"b.--",label=L"(67mA)")
plot(V2,I2,"r.--",label=L"(69.1mA)")
plot(V3,I3,"g.--",label=L"(69.1mA)")
title(L"60V \ (En \ los \ electrodos)",size=20)
legend(loc="best",fancybox="true")
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x119d17190>)

# %%
#promedio
Iprom=zeros(63)
for i in  1:63
    Iprom[i]=I1[i]+I2[i]+I3[i]
end 
plot(V1,Iprom,"c.--")
title(L"60V (promedio)",size=20)
#legend(loc="best",fancybox="true")
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11983c710>)

# %%
V1=zeros(67)
I1=zeros(67)
for i in 1:67
    V1[i]=sixtymA[i,1]
    I1[i]=sixtymA[i,2]
end 
plot(V1,I1,"b.--")
title(L"60 \ mA \ (1ra \ corrida)",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11a2262d0>)

# %%
V2=zeros(67)
I2=zeros(67)
for i in 1:67
    V2[i]=sixtymA[i,1]
    I2[i]=sixtymA[i,3]
end 
plot(V2,I2,"r.--")
title(L"60 \ mA \ (2da \ corrida)",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11a24e850>)

# %%
V3=zeros(67)
I3=zeros(67)
for i in 1:67
    V3[i]=sixtymA[i,1]
    I3[i]=sixtymA[i,4]
end 
plot(V3,I3,"g.--")
title(L"60 \ mA \ (3ra \ corrida)",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11a6fd9d0>)

# %%
plot(V1,I1,"b.--",label=L"1ra \ Corrida")
plot(V2,I2,"r.--",label=L"2da \ Corrida")
plot(V3,I3,"g.--",label=L"3ra \ Corrida")
legend(loc="best",fancybox="true")
title(L"60mA, \ 60.1V ",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11a94aa10>)

# %%
#promedio
Iprom=zeros(67)
for i in  1:67
    Iprom[i]=I1[i]+I2[i]+I3[i]
end 
plot(V1,Iprom,"c.--")
title(L"60mA (promedio)",size=20)
#legend(loc="best",fancybox="true")
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11abb5490>)

# %%
V1=zeros(67)
I1=zeros(67)
for i in 1:67
    V1[i]=fiftymA[i,1]
    I1[i]=fiftymA[i,2]
end 
plot(V1,I1,"b.--")
title(L"50 \ mA \ (1ra \ corrida)",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11aea30d0>)

# %%
V2=zeros(67)
I2=zeros(67)
for i in 1:67
    V2[i]=fiftymA[i,1]
    I2[i]=fiftymA[i,3]
end 
plot(V2,I2,"r.--")
title(L"50 \ mA \ (2da \ corrida)",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11a92b450>)

# %%
V3=zeros(67)
I3=zeros(67)
for i in 1:67
    V3[i]=fiftymA[i,1]
    I3[i]=fiftymA[i,4]
end 
plot(V3,I3,"g.--")
title(L"50 \ mA \ (3ra \ corrida)",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11abc7910>)

# %%
plot(V1,I1,"b.--",label=L"1ra \ Corrida")
plot(V2,I2,"r.--",label=L"2da \ Corrida")
plot(V3,I3,"g.--",label=L"3ra \ Corrida")
legend(loc="best",fancybox="true")
title(L"50mA, \ 59.2V ",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11986f6d0>)

# %%
#promedio
Iprom=zeros(67)
for i in  1:67
    Iprom[i]=I1[i]+I2[i]+I3[i]
end 
plot(V1,Iprom,"c.--")
title(L"50mA (promedio)",size=20)
#legend(loc="best",fancybox="true")
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11a6b1310>)

# %%
V1=zeros(67)
I1=zeros(67)
for i in 1:67
    V1[i]=fourtymA[i,1]
    I1[i]=fourtymA[i,2]
end 
plot(V1,I1,"b.--")
title(L"40 \ mA \ (1ra \ corrida)",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11a293b10>)

# %%
V2=zeros(67)
I2=zeros(67)
for i in 1:67
    V2[i]=fourtymA[i,1]
    I2[i]=fourtymA[i,3]
end 
plot(V2,I2,"b.--")
title(L"40 \ mA \ (2da \ corrida)",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1196173d0>)

# %%
V3=zeros(67)
I3=zeros(67)
for i in 1:67
    V3[i]=fourtymA[i,1]
    I3[i]=fourtymA[i,4]
end 
plot(V3,I3,"b.--")
title(L"40 \ mA \ (3ra \ corrida)",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x119d9f350>)

# %%
plot(V1,I1,"b.--",label=L"1ra \ Corrida")
plot(V2,I2,"r.--",label=L"2da \ Corrida")
plot(V3,I3,"g.--",label=L"3ra \ Corrida")
legend(loc="best",fancybox="true")
title(L"40mA, \ 57.8V ",size=20)
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x119cf38d0>)

# %%
#promedio
Iprom=zeros(67)
for i in  1:67
    Iprom[i]=I1[i]+I2[i]+I3[i]
end 
plot(V1,Iprom,"c.--")
title(L"40mA (promedio)",size=20)
#legend(loc="best",fancybox="true")
xlabel(L"Voltaje \ [V]",size=20)
ylabel(L"Corriente \ [mA]",size=20);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x119d60e90>)
